# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np
import tensorflow as tf
import pandas as pd
import re

# %%
batch_size = 64
epochs = 100
latent_dim = 256
num_samples = 10000

# %%
data_path = 'dataset/eng_to_hindi.xlsx'

# %%
DF = pd.read_excel(data_path)

# %%
# Randomly sample 10,000 rows
#df = DF.sample(n=10000)

# Select the first 10,000 rows
df = DF.head(15000)

# Select the last 10,000 rows
#df = DF.tail(10000)

# %%
input_text = df['English words/sentences']
input_text= input_text.astype(str)
input_text= input_text.apply(lambda x: x.lower())
input_text= input_text.apply(lambda x: re.sub("[^A-Za-z\s]","",x))
input_text= input_text.apply(lambda x: x.replace("\s+"," ")) # used for replacing one or more consecutive whitespace characters in a string with a single space.
input_text
# Out:
# 0                      hi
# 1                     run
# 2                     run
# 3                     who
# 4                     wow
#                ...
# 14995    i want to resign
# 14996    i want to resign
# 14997    i want to retire
# 14998    i want to retire
# 14999    i want to retire
# Name: English words/sentences, Length: 15000, dtype: object

# %%
target_text= df['Unnamed: 1'].astype(str)
# Convert text to lowercase (though Hindi is case-insensitive)
target_text= target_text.apply(lambda x: x.lower())
# Removing one or more consecutive whitespace
target_text= target_text.apply(lambda x: x.replace("\s+"," "))
 # Remove punctuation and special characters
target_text = target_text.apply(lambda x:re.sub(r'[^\w\s\u0900-\u097F]', '', x))  # Unicode range for Devanagari script
# Remove numbers
target_text = target_text.apply(lambda x:re.sub(r'\d+', '', x))
# Remove english alphabets
target_text = target_text.apply(lambda x: re.sub(r'[a-zA-Z]', '', x))
target_text= "\t "+target_text+" \n"
target_text
# Out:
# 0                           \t नमस्ते। \n
# 1                            \t दौड़ना \n
# 2                            \t दौड़ना \n
# 3                               \t कौन \n
# 4                          \t बहुत खूब \n
#                        ...
# 14995    \t मैं इस्तीफा देना चाहता हूं \n
# 14996    \t मैं इस्तीफा देना चाहता हूं \n
# 14997     \t मैं रिटायर होना चाहता हूं \n
# 14998     \t मैं रिटायर होना चाहता हूं \n
# 14999     \t मैं रिटायर होना चाहता हूं \n
# Name: Unnamed: 1, Length: 15000, dtype: object

# %%
# Creating lists of input and target lines
input_characters = set()
target_characters = set()
input_texts=[]
target_texts=[]

for lines in input_text:
    input_texts.append(lines)
    for char in lines:
        if char not in input_characters:
            input_characters.add(char)
    
for lines in target_text:
    target_texts.append(lines)
    for char in lines:
        if char not in target_characters:
            target_characters.add(char)

# %%
target_characters
# Out:
# {'\t',
#  '\n',
#  ' ',
#  'ँ',
#  'ं',
#  'ः',
#  'अ',
#  'आ',
#  'इ',
#  'ई',
#  'उ',
#  'ऊ',
#  'ऋ',
#  'ए',
#  'ऐ',
#  'ऑ',
#  'ओ',
#  'औ',
#  'क',
#  'ख',
#  'ग',
#  'घ',
#  'च',
#  'छ',
#  'ज',
#  'झ',
#  'ञ',
#  'ट',
#  'ठ',
#  'ड',
#  'ढ',
#  'ण',
#  'त',
#  'थ',
#  'द',
#  'ध',
#  'न',
#  'प',
#  'फ',
#  'ब',
#  'भ',
#  'म',
#  'य',
#  'र',
#  'ल',
#  'व',
#  'श',
#  'ष',
#  'स',
#  'ह',
#  '़',
#  'ा',
#  'ि',
#  'ी',
#  'ु',
#  'ू',
#  'ृ',
#  'ॅ',
#  'े',
#  'ै',
#  'ॉ',
#  'ो',
#  'ौ',
#  '्',
#  '।'}

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_len = max([len(txt) for txt in input_texts])
max_decoder_seq_len = max([len(txt) for txt in target_texts])

# %%
print('num of samples:', len(input_texts))
print('num of unique input tokens:', num_encoder_tokens)
print('num of unique output tokens:', num_decoder_tokens)
print('max seq len for inputs:', max_encoder_seq_len)
print('max seq len for outputs:', max_decoder_seq_len)
# Out:
# num of samples: 15000
# num of unique input tokens: 27
# num of unique output tokens: 65
# max seq len for inputs: 16
# max seq len for outputs: 48

# %%
input_texts
# Out:
# ['hi',
#  'run',
#  'run',
#  'who',
#  'wow',
#  'fire',
#  'help',
#  'jump',
#  'stop',
#  'stop',
#  'stop',
#  'wait',
#  'wait',
#  'go on',
#  'go on',
#  'go on',
#  'hello',
#  'hello',
#  'i see',
#  'i try',
#  'i won',
#  'i won',
#  'i won',
#  'oh no',
#  'attack',
#  'attack',
#  'cheers',
#  'cheers',
#  'cheers',
#  'cheers',
#  'get up',
#  'go now',
#  'go now',
#  'go now',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'hop in',
#  'hop in',
#  'hug me',
#  'hug me',
#  'i fell',
#  'i fell',
#  'i know',
#  'i left',
#  'i left',
#  'i lied',
#  'i lost',
#  'i paid',
#  'im ',
#  'im ok',
#  'im ok',
#  'listen',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'really',
#  'really',
#  'really',
#  'thanks',
#  'we try',
#  'we won',
#  'we won',
#  'we won',
#  'we won',
#  'ask tom',
#  'awesome',
#  'be calm',
#  'be calm',
#  'be calm',
#  'be cool',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be kind',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'beat it',
#  'call me',
#  'call me',
#  'call us',
#  'call us',
#  'come in',
#  'come in',
#  'come in',
#  'come in',
#  'come on',
#  'come on',
#  'come on',
#  'come on',
#  'drop it',
#  'drop it',
#  'drop it',
#  'drop it',
#  'get tom',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go home',
#  'go home',
#  'go home',
#  'go home',
#  'go slow',
#  'go slow',
#  'goodbye',
#  'goodbye',
#  'hang on',
#  'hang on',
#  'hang on',
#  'hang on',
#  'he quit',
#  'he quit',
#  'he runs',
#  'help me',
#  'help me',
#  'help me',
#  'help us',
#  'help us',
#  'hold it',
#  'hold on',
#  'hug tom',
#  'i agree',
#  'i cried',
#  'i dozed',
#  'i dozed',
#  'i drive',
#  'i smoke',
#  'i snore',
#  'i stink',
#  'i stood',
#  'i stood',
#  'i swore',
#  'i swore',
#  'i tried',
#  'i tried',
#  'i tried',
#  'i waved',
#  'ill go',
#  'im tom',
#  'im fat',
#  'im fat',
#  'im fit',
#  'im hit',
#  'im hit',
#  'im ill',
#  'im sad',
#  'im shy',
#  'im wet',
#  'im wet',
#  'its me',
#  'join us',
#  'join us',
#  'keep it',
#  'keep it',
#  'kiss me',
#  'kiss me',
#  'me too',
#  'open up',
#  'open up',
#  'perfect',
#  'see you',
#  'see you',
#  'see you',
#  'see you',
#  'show me',
#  'show me',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'skip it',
#  'so long',
#  'take it',
#  'take it',
#  'take it',
#  'take it',
#  'tell me',
#  'tell me',
#  'tom won',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wash up',
#  'wash up',
#  'we know',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'welcome',
#  'who won',
#  'who won',
#  'you run',
#  'am i fat',
#  'am i fat',
#  'ask them',
#  'ask them',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'be a man',
#  'be a man',
#  'be still',
#  'be still',
#  'be still',
#  'beats me',
#  'beats me',
#  'call tom',
#  'call tom',
#  'cheer up',
#  'cool off',
#  'cuff him',
#  'drive on',
#  'drive on',
#  'drive on',
#  'drive on',
#  'find tom',
#  'find tom',
#  'fix this',
#  'fix this',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get lost',
#  'get lost',
#  'get lost',
#  'get real',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'good job',
#  'good job',
#  'good job',
#  'grab him',
#  'grab him',
#  'have fun',
#  'have fun',
#  'he tries',
#  'hes wet',
#  'help tom',
#  'help tom',
#  'hi guys',
#  'how cute',
#  'how deep',
#  'how nice',
#  'how nice',
#  'how nice',
#  'how nice',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'i did ok',
#  'i did ok',
#  'i did it',
#  'i did it',
#  'i failed',
#  'i forgot',
#  'i get it',
#  'i got it',
#  'i got it',
#  'i helped',
#  'i jumped',
#  'i looked',
#  'i moaned',
#  'i nodded',
#  'i obeyed',
#  'i phoned',
#  'i phoned',
#  'i refuse',
#  'i refuse',
#  'i rested',
#  'i rested',
#  'i saw it',
#  'i saw it',
#  'i sighed',
#  'i stayed',
#  'i stayed',
#  'i talked',
#  'i use it',
#  'i use it',
#  'i use it',
#  'ill pay',
#  'ill try',
#  'ill try',
#  'im back',
#  'im back',
#  'im bald',
#  'im busy',
#  'im busy',
#  'im calm',
#  'im cold',
#  'im cool',
#  'im cool',
#  'im deaf',
#  'im deaf',
#  'im done',
#  'im fair',
#  'im fair',
#  'im fair',
#  'im fast',
#  'im fine',
#  'im fine',
#  'im fine',
#  'im free',
#  'im free',
#  'im free',
#  'im full',
#  'im full',
#  'im game',
#  'im game',
#  'im glad',
#  'im home',
#  'im late',
#  'im lazy',
#  'im lazy',
#  'im lazy',
#  'im lazy',
#  'im okay',
#  'im okay',
#  'im rich',
#  'im safe',
#  'im sick',
#  'im sure',
#  'im sure',
#  'im sure',
#  'im sure',
#  'im tall',
#  'im thin',
#  'im tidy',
#  'im tidy',
#  'im ugly',
#  'im ugly',
#  'im weak',
#  'im well',
#  'im well',
#  'ive won',
#  'ive won',
#  'it helps',
#  'it hurts',
#  'it works',
#  'it works',
#  'its tom',
#  'its fun',
#  'its fun',
#  'its his',
#  'its his',
#  'its new',
#  'its new',
#  'its odd',
#  'its red',
#  'its sad',
#  'keep out',
#  'keep out',
#  'kiss tom',
#  'leave it',
#  'leave it',
#  'leave me',
#  'leave us',
#  'leave us',
#  'lets go',
#  'lets go',
#  'look out',
#  'look out',
#  'marry me',
#  'marry me',
#  'may i go',
#  'may i go',
#  'may i go',
#  'save tom',
#  'save tom',
#  'say what',
#  'she came',
#  'she died',
#  'she runs',
#  'sit down',
#  'sit down',
#  'sit down',
#  'sit here',
#  'sit here',
#  'speak up',
#  'speak up',
#  'stand up',
#  'stop tom',
#  'stop tom',
#  'taste it',
#  'taste it',
#  'taste it',
#  'taste it',
#  'tell tom',
#  'tell tom',
#  'terrific',
#  'terrific',
#  'terrific',
#  'they won',
#  'they won',
#  'they won',
#  'they won',
#  'tom came',
#  'tom died',
#  'tom knew',
#  'tom left',
#  'tom left',
#  'tom lied',
#  'tom lies',
#  'tom lost',
#  'tom paid',
#  'too late',
#  'trust me',
#  'trust me',
#  'try hard',
#  'try some',
#  'try some',
#  'try this',
#  'try this',
#  'use this',
#  'use this',
#  'use this',
#  'use this',
#  'warn tom',
#  'warn tom',
#  'watch me',
#  'watch me',
#  'watch us',
#  'watch us',
#  'we agree',
#  'well go',
#  'were ok',
#  'what for',
#  'what for',
#  'what fun',
#  'what fun',
#  'who came',
#  'who died',
#  'who fell',
#  'who quit',
#  'whos he',
#  'write me',
#  'write me',
#  'you lost',
#  'you lost',
#  'after you',
#  'aim fire',
#  'am i late',
#  'answer me',
#  'be seated',
#  'be seated',
#  'birds fly',
#  'bless you',
#  'call home',
#  'calm down',
#  'calm down',
#  'can we go',
#  'can we go',
#  'can we go',
#  'catch tom',
#  'catch tom',
#  'catch him',
#  'chill out',
#  'come back',
#  'come back',
#  'come here',
#  'come here',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come soon',
#  'come soon',
#  'cool down',
#  'did i win',
#  'did i win',
#  'did i win',
#  'do it now',
#  'dogs bark',
#  'dogs bark',
#  'dont ask',
#  'dont cry',
#  'dont die',
#  'dont die',
#  'dont lie',
#  'dont run',
#  'dont run',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'fantastic',
#  'feel this',
#  'feel this',
#  'feel this',
#  'feel this',
#  'follow me',
#  'follow us',
#  'follow us',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get ready',
#  'get ready',
#  'go get it',
#  'go get it',
#  'go inside',
#  'go to bed',
#  'go to bed',
#  'good luck',
#  'good luck',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab this',
#  'grab this',
#  'hands off',
#  'he is ill',
#  'he is old',
#  'hes a dj',
#  'hes good',
#  'hes lazy',
#  'hes mine',
#  'hes rich',
#  'hes sexy',
#  'here i am',
#  'heres ',
#  'hold fire',
#  'hold fire',
#  'hold this',
#  'hold this',
#  'hold this',
#  'hold this',
#  'how awful',
#  'how weird',
#  'hows tom',
#  'hows tom',
#  'i am cold',
#  'i am good',
#  'i am okay',
#  'i am sick',
#  'i am sure',
#  'i am sure',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i can run',
#  'i can ski',
#  'i cringed',
#  'i cringed',
#  'i cringed',
#  'i exhaled',
#  'i gave up',
#  'i give in',
#  'i give up',
#  'i got hot',
#  'i got hot',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i hate it',
#  'i have it',
#  'i hit tom',
#  'i hope so',
#  'i hurried',
#  'i hurried',
#  'i inhaled',
#  'i knew it',
#  'i like it',
#  'i lost it',
#  'i love it',
#  'i love it',
#  'i mean it',
#  'i mean it',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i need it',
#  'i need it',
#  'i noticed',
#  'i prepaid',
#  'i promise',
#  'i relaxed',
#  'i relaxed',
#  'i retired',
#  'i said no',
#  'i said so',
#  'i saw him',
#  'i saw him',
#  'i saw him',
#  'i saw one',
#  'i saw one',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i see tom',
#  'i shouted',
#  'i tripped',
#  'i tripped',
#  'i want it',
#  'i was new',
#  'i was new',
#  'i will go',
#  'i woke up',
#  'i woke up',
#  'id agree',
#  'id leave',
#  'ill call',
#  'ill cook',
#  'ill help',
#  'ill live',
#  'ill obey',
#  'ill pack',
#  'ill pack',
#  'ill pack',
#  'ill pass',
#  'ill quit',
#  'ill sing',
#  'ill stop',
#  'ill swim',
#  'ill talk',
#  'ill talk',
#  'ill wait',
#  'ill walk',
#  'ill work',
#  'ill work',
#  'im a cop',
#  'im a man',
#  'im alive',
#  'im alive',
#  'im alive',
#  'im alone',
#  'im alone',
#  'im angry',
#  'im angry',
#  'im armed',
#  'im armed',
#  'im awake',
#  'im blind',
#  'im broke',
#  'im clean',
#  'im clean',
#  'im crazy',
#  'im crazy',
#  'im cured',
#  'im cured',
#  'im dizzy',
#  'im drunk',
#  'im drunk',
#  'im drunk',
#  'im dying',
#  'im early',
#  'im first',
#  'im fussy',
#  'im fussy',
#  'im fussy',
#  'im going',
#  'im going',
#  'im going',
#  'im going',
#  'im loyal',
#  'im loyal',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lying',
#  'im naked',
#  'im naked',
#  'im naked',
#  'im naked',
#  'im naked',
#  'im quiet',
#  'im ready',
#  'im ready',
#  'im ready',
#  'im right',
#  'im sober',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im stuck',
#  'im timid',
#  'im tired',
#  'im tough',
#  'im tough',
#  'im tough',
#  'im tough',
#  'im yours',
#  'im yours',
#  'ive lost',
#  'is tom ok',
#  'is tom ok',
#  'is it bad',
#  'is it far',
#  'is it far',
#  'is it hot',
#  'is it you',
#  'is it you',
#  'is it you',
#  'it failed',
#  'it snowed',
#  'it stinks',
#  'it stinks',
#  'it was ok',
#  'it was ok',
#  'it was ok',
#  'it worked',
#  'it worked',
#  'its ',
#  'its ',
#  'its ',
#  'its a tv',
#  'its cold',
#  'its cold',
#  'its dark',
#  'its dead',
#  'its dead',
#  'its dead',
#  'its done',
#  'its easy',
#  'its food',
#  'its free',
#  'its here',
#  'its here',
#  'its hers',
#  'its hers',
#  'its late',
#  'its lost',
#  'its mine',
#  'its mine',
#  'its mine',
#  'its mine',
#  'its open',
#  'its ours',
#  'its ours',
#  'its ours',
#  'its sand',
#  'its time',
#  'its time',
#  'its true',
#  'its work',
#  'keep calm',
#  'keep that',
#  'keep that',
#  'keep this',
#  'keep this',
#  'let it be',
#  'let it be',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me in',
#  'let me in',
#  'lets ask',
#  'lets eat',
#  'lets see',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'look away',
#  'look away',
#  'look back',
#  'look back',
#  'look here',
#  'look here',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'move over',
#  'move over',
#  'move over',
#  'nice shot',
#  'of course',
#  'of course',
#  'of course',
#  'of course',
#  'of course',
#  'oh please',
#  'oh please',
#  'pardon me',
#  'pardon me',
#  'pardon me',
#  'read this',
#  'say hello',
#  'see above',
#  'see below',
#  'see below',
#  'seize him',
#  'seize him',
#  'seriously',
#  'seriously',
#  'seriously',
#  'she cried',
#  'she cried',
#  'she tried',
#  'she walks',
#  'shes hot',
#  'shes hot',
#  'sign here',
#  'sign here',
#  'sign this',
#  'sign this',
#  'slow down',
#  'slow down',
#  'stay away',
#  'stay away',
#  'stay back',
#  'stay back',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay down',
#  'stay down',
#  'stay down',
#  'stay down',
#  'stay here',
#  'stay here',
#  'stay here',
#  'stay thin',
#  'step back',
#  'step back',
#  'stop that',
#  'stop that',
#  'stop that',
#  'stop that',
#  'stop them',
#  'take care',
#  'take care',
#  'take care',
#  'take care',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take this',
#  'take this',
#  'thank you',
#  'thank you',
#  'thats ok',
#  'thats ok',
#  'thats ok',
#  'thats ok',
#  'thats it',
#  'then what',
#  'they fell',
#  'they fell',
#  'they left',
#  'they left',
#  'they lied',
#  'they lied',
#  'they lost',
#  'they lost',
#  'they swam',
#  'they swam',
#  'they swam',
#  'they swam',
#  'times up',
#  'tom cooks',
#  'tom cried',
#  'tom is ok',
#  'tom knits',
#  'tom knows',
#  'tom rocks',
#  'tom spoke',
#  'tom waved',
#  'tom works',
#  'toms fat',
#  'toms mad',
#  'toms mad',
#  'toms sad',
#  'trust tom',
#  'trust tom',
#  'try again',
#  'try again',
#  'try again',
#  'try it on',
#  'turn left',
#  'wait here',
#  'wait here',
#  'wait here',
#  'wait here',
#  'watch out',
#  'watch out',
#  'watch out',
#  'we agreed',
#  'we did it',
#  'we did it',
#  'we did it',
#  'we forgot',
#  'we saw it',
#  'we saw it',
#  'we smiled',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we waited',
#  'we waited',
#  'we walked',
#  'we walked',
#  'well try',
#  'well try',
#  'well win',
#  'well win',
#  'were hot',
#  'were sad',
#  ...]

# %%
target_texts
# Out:
# ['\t नमस्ते। \n',
#  '\t दौड़ना \n',
#  '\t दौड़ना \n',
#  '\t कौन \n',
#  '\t बहुत खूब \n',
#  '\t आग \n',
#  '\t मदद करना \n',
#  '\t कूदना। \n',
#  '\t रुकना \n',
#  '\t रुकना \n',
#  '\t रुकना \n',
#  '\t इंतज़ार \n',
#  '\t इंतज़ार \n',
#  '\t जारी रखें। \n',
#  '\t जारी रखें। \n',
#  '\t जारी रखें। \n',
#  '\t नमस्ते \n',
#  '\t नमस्ते \n',
#  '\t अच्छा ऐसा है। \n',
#  '\t मैं कोशिश करता हूँ। \n',
#  '\t मैं जीत गया \n',
#  '\t मैं जीत गया \n',
#  '\t मैं जीत गया \n',
#  '\t अरे नहीं \n',
#  '\t आक्रमण करना \n',
#  '\t आक्रमण करना \n',
#  '\t प्रोत्साहित करना \n',
#  '\t प्रोत्साहित करना \n',
#  '\t प्रोत्साहित करना \n',
#  '\t प्रोत्साहित करना \n',
#  '\t उठना। \n',
#  '\t अब जाओ। \n',
#  '\t अब जाओ। \n',
#  '\t अब जाओ। \n',
#  '\t समझ गया \n',
#  '\t समझ गया \n',
#  '\t समझ गया \n',
#  '\t समझ गया \n',
#  '\t समझ गया \n',
#  '\t अंदर कूदो \n',
#  '\t अंदर कूदो \n',
#  '\t मुझे गले लगाओ। \n',
#  '\t मुझे गले लगाओ। \n',
#  '\t मैं गिर गया। \n',
#  '\t मैं गिर गया। \n',
#  '\t मुझे पता है। \n',
#  '\t मैंने। \n',
#  '\t मैंने। \n',
#  '\t मैंने झूठ बोला \n',
#  '\t मेरी हार हुई। \n',
#  '\t मैंने भुगतान कर दिया है। \n',
#  '\t मैं  साल का हूं \n',
#  '\t मैं ठीक हूं। \n',
#  '\t मैं ठीक हूं। \n',
#  '\t सुनना। \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t बिलकुल नहीं \n',
#  '\t वास्तव में \n',
#  '\t वास्तव में \n',
#  '\t वास्तव में \n',
#  '\t धन्यवाद। \n',
#  '\t हम कोशिश करेंगे। \n',
#  '\t हम जीत गये \n',
#  '\t हम जीत गये \n',
#  '\t हम जीत गये \n',
#  '\t हम जीत गये \n',
#  '\t टॉम से पूछो \n',
#  '\t बहुत बढ़िया \n',
#  '\t शांत रहो। \n',
#  '\t शांत रहो। \n',
#  '\t शांत रहो। \n',
#  '\t शांत हों। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t निष्पक्ष हो। \n',
#  '\t दयालु हों। \n',
#  '\t अच्छा होगा। \n',
#  '\t अच्छा होगा। \n',
#  '\t अच्छा होगा। \n',
#  '\t अच्छा होगा। \n',
#  '\t अच्छा होगा। \n',
#  '\t अच्छा होगा। \n',
#  '\t इसे हरायें। \n',
#  '\t मुझे कॉल करो। \n',
#  '\t मुझे कॉल करो। \n',
#  '\t हमें कॉल करें \n',
#  '\t हमें कॉल करें \n',
#  '\t अंदर आएं। \n',
#  '\t अंदर आएं। \n',
#  '\t अंदर आएं। \n',
#  '\t अंदर आएं। \n',
#  '\t चलो भी \n',
#  '\t चलो भी। \n',
#  '\t चलो भी। \n',
#  '\t चलो भी। \n',
#  '\t जाने दो \n',
#  '\t जाने दो \n',
#  '\t जाने दो \n',
#  '\t जाने दो \n',
#  '\t टॉम प्राप्त करें \n',
#  '\t चले जाओ \n',
#  '\t चले जाओ \n',
#  '\t चले जाओ \n',
#  '\t चले जाओ। \n',
#  '\t चले जाओ। \n',
#  '\t दूर जाओ \n',
#  '\t दूर जाओ \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t दूर जाओ। \n',
#  '\t घर जाओ \n',
#  '\t घर जाओ \n',
#  '\t घर जाओ \n',
#  '\t घर जाओ \n',
#  '\t धीरे जाइये। \n',
#  '\t धीरे जाइये। \n',
#  '\t अलविदा \n',
#  '\t अलविदा \n',
#  '\t डटे रहो \n',
#  '\t डटे रहो \n',
#  '\t डटे रहो। \n',
#  '\t डटे रहो। \n',
#  '\t उसने छोड़ दिया। \n',
#  '\t उसने छोड़ दिया। \n',
#  '\t वह दौड़ता है। \n',
#  '\t मेरी सहायता करो \n',
#  '\t मेरी सहायता करो। \n',
#  '\t मेरी सहायता करो। \n',
#  '\t हमारी मदद करें। \n',
#  '\t हमारी मदद करें। \n',
#  '\t इसे पकड़ो \n',
#  '\t पकड़ना। \n',
#  '\t टॉम को गले लगाओ \n',
#  '\t मैं सहमत हूं। \n',
#  '\t मैं रोया। \n',
#  '\t मुझे झपकी आ गयी \n',
#  '\t मुझे झपकी आ गयी \n',
#  '\t मैं ड्राइव करता हूँ। \n',
#  '\t मैं धूम्रपान करता हूँ \n',
#  '\t मैं खर्राटे लेता हूँ \n',
#  '\t मैं बदबू मारता हूं। \n',
#  '\t मैं खड़ा रहा \n',
#  '\t मैं खड़ा रहा \n',
#  '\t मैंने कसम खाई \n',
#  '\t मैंने कसम खाई \n',
#  '\t मैंने कोशिश की \n',
#  '\t मैंने कोशिश की \n',
#  '\t मैंने कोशिश की \n',
#  '\t मैंने लहराया। \n',
#  '\t मैं जाऊंगा \n',
#  '\t मैं टॉम हूं \n',
#  '\t मैं मोटा हूँ \n',
#  '\t मैं मोटा हूँ \n',
#  '\t मैं फिट हूं। \n',
#  '\t मैंने मारा \n',
#  '\t मैंने मारा \n',
#  '\t मैं बीमार हूं \n',
#  '\t मैं दुखी हूं। \n',
#  '\t मैं शर्मीला हूँ \n',
#  '\t मै गीला हूँ। \n',
#  '\t मै गीला हूँ। \n',
#  '\t यह मैं हूं \n',
#  '\t हमसे जुड़ें \n',
#  '\t हमसे जुड़ें \n',
#  '\t इसे रखें। \n',
#  '\t इसे रखें। \n',
#  '\t मुझे किस करो। \n',
#  '\t मुझे किस करो। \n',
#  '\t मैं भी। \n',
#  '\t खुलना। \n',
#  '\t खुलना। \n',
#  '\t उत्तम \n',
#  '\t फिर मिलते हैं \n',
#  '\t फिर मिलते हैं \n',
#  '\t फिर मिलते हैं \n',
#  '\t फिर मिलते हैं। \n',
#  '\t मुझे दिखाओ। \n',
#  '\t मुझे दिखाओ। \n',
#  '\t चुप रहो \n',
#  '\t चुप रहो \n',
#  '\t चुप रहो \n',
#  '\t चुप रहो \n',
#  '\t चुप रहो \n',
#  '\t इसे छोड़ दें। \n',
#  '\t इतना लंबा \n',
#  '\t इसे लें। \n',
#  '\t इसे लें। \n',
#  '\t इसे लें। \n',
#  '\t इसे लें। \n',
#  '\t मुझे बताओ। \n',
#  '\t मुझे बताओ। \n',
#  '\t टॉम जीत गया \n',
#  '\t जागो \n',
#  '\t जागो \n',
#  '\t जागो \n',
#  '\t जागो। \n',
#  '\t जागो। \n',
#  '\t नहाना। \n',
#  '\t नहाना। \n',
#  '\t हम जानते हैं। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t हमने खो दिया। \n',
#  '\t स्वागत। \n',
#  '\t कौन जीता \n',
#  '\t कौन जीता \n',
#  '\t तुम दौड़ो \n',
#  '\t क्या मैं मोटा हूँ \n',
#  '\t क्या मैं मोटा हूँ \n',
#  '\t उन्हें पूछना। \n',
#  '\t उन्हें पूछना। \n',
#  '\t पीछे हटना \n',
#  '\t पीछे हटना \n',
#  '\t पीछे हटना। \n',
#  '\t पीछे हटना। \n',
#  '\t पीछे हटना। \n',
#  '\t पीछे हटना। \n',
#  '\t एक आदमी बनों। \n',
#  '\t एक आदमी बनों। \n',
#  '\t अभी भी हो। \n',
#  '\t अभी भी हो। \n',
#  '\t अभी भी हो। \n',
#  '\t मुझे पता नहीं। \n',
#  '\t मुझे पता नहीं। \n',
#  '\t टॉम को बुलाओ \n',
#  '\t टॉम को बुलाओ \n',
#  '\t खुश हो जाओ \n',
#  '\t ठंडा करें \n',
#  '\t उसे जकड़ लो \n',
#  '\t आगे बढ़ें \n',
#  '\t आगे बढ़ें \n',
#  '\t आगे बढ़ें \n',
#  '\t आगे बढ़ें \n',
#  '\t टॉम को खोजें \n',
#  '\t टॉम को खोजें \n',
#  '\t इसे ठीक करें \n',
#  '\t इसे ठीक करें \n',
#  '\t नीचे उतरो \n',
#  '\t नीचे उतरो। \n',
#  '\t नीचे उतरो। \n',
#  '\t नीचे उतरो। \n',
#  '\t नीचे उतरो। \n',
#  '\t भाड़ में जाओ \n',
#  '\t भाड़ में जाओ \n',
#  '\t भाड़ में जाओ \n',
#  '\t असली लें \n',
#  '\t आगे बढ़ो \n',
#  '\t आगे बढ़ो \n',
#  '\t आगे बढ़ो \n',
#  '\t आगे बढ़ो। \n',
#  '\t आगे बढ़ो। \n',
#  '\t आगे बढ़ो। \n',
#  '\t आगे बढ़ो। \n',
#  '\t अच्छा काम \n',
#  '\t अच्छा काम \n',
#  '\t अच्छा काम \n',
#  '\t उसे पकड़ो \n',
#  '\t उसे पकड़ो \n',
#  '\t मस्ती करो। \n',
#  '\t मस्ती करो। \n',
#  '\t वह कोशिश करता है। \n',
#  '\t वह गीला है \n',
#  '\t टॉम की मदद करो \n',
#  '\t टॉम की मदद करो \n',
#  '\t हाय दोस्तों। \n',
#  '\t कितना प्यारा \n',
#  '\t कितना गहरा \n',
#  '\t कितना अच्छा \n',
#  '\t कितना अच्छा \n',
#  '\t कितना अच्छा \n',
#  '\t कितना अच्छा \n',
#  '\t जल्दी करो। \n',
#  '\t जल्दी करो। \n',
#  '\t जल्दी करो। \n',
#  '\t जल्दी करो। \n',
#  '\t मैंने ठीक किया \n',
#  '\t मैंने ठीक किया \n',
#  '\t मैंने यह किया है। \n',
#  '\t मैंने यह किया है। \n',
#  '\t में विफल रहा है। \n',
#  '\t मैं भूल गया \n',
#  '\t मैं समझ गया। \n',
#  '\t मैं समझ गया। \n',
#  '\t मैं समझ गया। \n',
#  '\t मैंने मदद की। \n',
#  '\t मैं उछल पड़ा \n',
#  '\t मैंने देखा \n',
#  '\t मैं कराह उठा \n',
#  '\t मेंने सिर हिलाया। \n',
#  '\t मैंने आज्ञा मानी \n',
#  '\t मैंने फ़ोन किया \n',
#  '\t मैंने फ़ोन किया \n',
#  '\t मैंने मना कर दिया। \n',
#  '\t मैंने मना कर दिया। \n',
#  '\t मैंने आराम किया \n',
#  '\t मैंने आराम किया \n',
#  '\t मैंने उसे देखा। \n',
#  '\t मैंने उसे देखा। \n',
#  '\t मैंने आह भरी \n',
#  '\t मैं रुका रहा। \n',
#  '\t मैं रुका रहा। \n',
#  '\t मैंनें बात की। \n',
#  '\t मैंने इसका उपयोग किया। \n',
#  '\t मैंने इसका उपयोग किया। \n',
#  '\t मैंने इसका उपयोग किया। \n',
#  '\t मैं भुगतान करूंगा \n',
#  '\t मेँ कोशिश करुंगा। \n',
#  '\t मेँ कोशिश करुंगा। \n',
#  '\t मैं वापस आ गया हूं। \n',
#  '\t मैं वापस आ गया हूं। \n',
#  '\t मेरे सिर पर बाल नहीं है। \n',
#  '\t मैं व्यस्त हूं। \n',
#  '\t मैं व्यस्त हूं। \n',
#  '\t मैं शांत हूं \n',
#  '\t मुझे ठंड लग रही है। \n',
#  '\t मैं ठीक हूँ। \n',
#  '\t मैं ठीक हूँ। \n',
#  '\t मैं बहरा हूँ \n',
#  '\t मैं बहरा हूँ \n',
#  '\t मेरा काम हो गया। \n',
#  '\t मैं सही हूं। \n',
#  '\t मैं सही हूं। \n',
#  '\t मैं सही हूं। \n',
#  '\t मैं तेज़ हूँ \n',
#  '\t मैं ठीक हूँ। \n',
#  '\t मैं ठीक हूँ। \n',
#  '\t मैं ठीक हूँ। \n',
#  '\t मैं व्यस्त नहीं हूं \n',
#  '\t मैं व्यस्त नहीं हूं। \n',
#  '\t मैं व्यस्त नहीं हूं। \n',
#  '\t मेरा पेट भर चुका है। \n',
#  '\t मेरा पेट भर चुका है। \n',
#  '\t मैं खेल रहा हूँ। \n',
#  '\t मैं खेल रहा हूँ। \n',
#  '\t मैं खुश हूं। \n',
#  '\t मेँ घर पर हूँ। \n',
#  '\t मुझे देर हो गई। \n',
#  '\t मैं आलसी हूं \n',
#  '\t मैं आलसी हूं \n',
#  '\t मैं आलसी हूं \n',
#  '\t मैं आलसी हूं \n',
#  '\t मैं ठीक हूं \n',
#  '\t मैं ठीक हूं \n',
#  '\t मैं अमीर हूँ। \n',
#  '\t मैं सुरक्षित हूं। \n',
#  '\t मैं बीमार हूं। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मैं लंबा हूँ। \n',
#  '\t मैं पतली हूँ। \n',
#  '\t मैं साफसुथरा हूं \n',
#  '\t मैं साफसुथरा हूं \n',
#  '\t मैं बदसूरत हूँ \n',
#  '\t मैं बदसूरत हूँ \n',
#  '\t मैं कमजोर हूं \n',
#  '\t मैं अच्छा हूँ। \n',
#  '\t मैं अच्छा हूँ। \n',
#  '\t मैं जीत गया। \n',
#  '\t मैं जीत गया। \n',
#  '\t इससे मदद मिलती है \n',
#  '\t यह दुखदायक है। \n',
#  '\t यह काम करता है। \n',
#  '\t यह काम करता है। \n',
#  '\t यह टॉम है \n',
#  '\t मजा आता है। \n',
#  '\t मजा आता है। \n',
#  '\t यह है उसकी। \n',
#  '\t यह है उसकी। \n',
#  '\t यह नया है \n',
#  '\t यह नया है \n',
#  '\t यह अजीब है \n',
#  '\t यह लाल है \n',
#  '\t यह दुखद है \n',
#  '\t दूर रहो \n',
#  '\t दूर रहो। \n',
#  '\t टॉम को चूमो \n',
#  '\t इसे छोड़ो। \n',
#  '\t इसे छोड़ो। \n',
#  '\t मुझे छोड़ दो। \n',
#  '\t हमे छोड़ दो। \n',
#  '\t हमे छोड़ दो। \n',
#  '\t चल दर \n',
#  '\t चल दर। \n',
#  '\t बाहर देखो \n',
#  '\t बाहर देखो \n',
#  '\t मुझसे विवाह करो। \n',
#  '\t मुझसे विवाह करो। \n',
#  '\t क्या मैं जा सकता हुँ \n',
#  '\t क्या मैं जा सकता हुँ \n',
#  '\t क्या मैं जा सकता हुँ \n',
#  '\t टॉम को बचाओ \n',
#  '\t टॉम को बचाओ \n',
#  '\t क्या कहना \n',
#  '\t वह आया। \n',
#  '\t वह मर गई। \n',
#  '\t वह भागती है। \n',
#  '\t बैठो \n',
#  '\t बैठो \n',
#  '\t बैठ जाओ \n',
#  '\t यहाँ बैठो। \n',
#  '\t यहाँ बैठो। \n',
#  '\t घोषित करना \n',
#  '\t घोषित करना \n',
#  '\t खड़े हो जाओ \n',
#  '\t टॉम रुको \n',
#  '\t टॉम रुको \n',
#  '\t इसे चखें। \n',
#  '\t इसे चखें। \n',
#  '\t इसे चखें। \n',
#  '\t इसे चखें। \n',
#  '\t टॉम को बताओ \n',
#  '\t टॉम को बताओ \n',
#  '\t कमाल का \n',
#  '\t कमाल का \n',
#  '\t कमाल का \n',
#  '\t वे जीत गये। \n',
#  '\t वे जीत गये। \n',
#  '\t वे जीत गये। \n',
#  '\t वे जीत गये। \n',
#  '\t टॉम आया \n',
#  '\t टॉम मर गया \n',
#  '\t टॉम जानता था \n',
#  '\t टॉम चला गया \n',
#  '\t टॉम चला गया \n',
#  '\t टॉम ने झूठ बोला \n',
#  '\t टॉम झूठ बोलता है \n',
#  '\t टॉम हार गया \n',
#  '\t टॉम ने भुगतान किया \n',
#  '\t बहुत देर हो गई। \n',
#  '\t मुझ पर भरोसा करें। \n',
#  '\t मुझ पर भरोसा करें। \n',
#  '\t कठिन प्रयास। \n',
#  '\t कुछ कोशिश करो। \n',
#  '\t कुछ कोशिश करो। \n',
#  '\t ये कोशिश करें। \n',
#  '\t ये कोशिश करें। \n',
#  '\t इस का उपयोग करें। \n',
#  '\t इस का उपयोग करें। \n',
#  '\t इस का उपयोग करें। \n',
#  '\t इस का उपयोग करें। \n',
#  '\t टॉम को चेतावनी दें \n',
#  '\t टॉम को चेतावनी दें \n',
#  '\t मुझे देखो \n',
#  '\t मुझे देखो \n',
#  '\t हमें देखें। \n',
#  '\t हमें देखें। \n',
#  '\t हम सहमत। \n',
#  '\t हम जायेंगे। \n',
#  '\t हम ठीक हैं \n',
#  '\t किसलिए \n',
#  '\t किसलिए \n',
#  '\t कितना मजेदार \n',
#  '\t कितना मजेदार \n',
#  '\t कौन आया \n',
#  '\t कौन मरा \n',
#  '\t कौन गिरा \n',
#  '\t किसने छोड़ा \n',
#  '\t वह कौन है \n',
#  '\t मुझे लिखें \n',
#  '\t मुझे लिखें \n',
#  '\t आपने खो दिया। \n',
#  '\t आपने खो दिया। \n',
#  '\t आप के बाद \n',
#  '\t उद्देश्य। आग \n',
#  '\t क्या मैं देर से आया हूँ \n',
#  '\t मुझे जवाब दें। \n',
#  '\t बैठ जाओ \n',
#  '\t बैठ जाओ \n',
#  '\t पक्षियों की उड़ान भरने। \n',
#  '\t तुम्हें आशीर्वाद देते हैं। \n',
#  '\t घर पर कॉल करें \n',
#  '\t शांत हो जाएं \n',
#  '\t शांत हो जाएं। \n',
#  '\t क्या हम जा सकते हैं \n',
#  '\t क्या हम जा सकते हैं \n',
#  '\t क्या हम जा सकते हैं \n',
#  '\t टॉम को पकड़ो \n',
#  '\t टॉम को पकड़ो \n',
#  '\t उसे पकड़ने। \n',
#  '\t मज़े करें। \n',
#  '\t वापस आओ। \n',
#  '\t वापस आओ। \n',
#  '\t यहाँ आओ। \n',
#  '\t यहाँ आओ। \n',
#  '\t मिलने आना \n',
#  '\t मिलने आना \n',
#  '\t मिलने आना। \n',
#  '\t मिलने आना। \n',
#  '\t मिलने आना। \n',
#  '\t मिलने आना। \n',
#  '\t मिलने आना। \n',
#  '\t जल्दी आओ। \n',
#  '\t जल्दी आओ। \n',
#  '\t शांत हो जाओ। \n',
#  '\t क्या मैंने जीत लिया \n',
#  '\t क्या मैंने जीत लिया \n',
#  '\t क्या मैंने जीत लिया \n',
#  '\t अभी करो। \n',
#  '\t कुत्ते भौंकते हैं। \n',
#  '\t कुत्ते भौंकते हैं। \n',
#  '\t मत पूछो \n',
#  '\t रोओ मत \n',
#  '\t मरो मत \n',
#  '\t मरो मत \n',
#  '\t झूठ मत बोलो \n',
#  '\t भागो मत \n',
#  '\t भागो मत \n',
#  '\t माफ़ करें। \n',
#  '\t माफ़ करें। \n',
#  '\t माफ़ करें \n',
#  '\t माफ़ करें \n',
#  '\t माफ़ करें \n',
#  '\t माफ़ करें \n',
#  '\t माफ़ करें \n',
#  '\t ज़बरदस्त \n',
#  '\t इसे महसूस करो \n',
#  '\t इसे महसूस करो \n',
#  '\t इसे महसूस करो \n',
#  '\t इसे महसूस करो \n',
#  '\t मेरे पीछे आओ। \n',
#  '\t हमारे पर का पालन करें। \n',
#  '\t हमारे पर का पालन करें। \n',
#  '\t रहने भी दो \n',
#  '\t रहने भी दो \n',
#  '\t रहने भी दो \n',
#  '\t रहने भी दो \n',
#  '\t रहने भी दो। \n',
#  '\t रहने भी दो। \n',
#  '\t रहने भी दो। \n',
#  '\t नौकरी मिलना। \n',
#  '\t नौकरी मिलना। \n',
#  '\t नौकरी मिलना। \n',
#  '\t नौकरी मिलना। \n',
#  '\t तैयार हो जाओ। \n',
#  '\t तैयार हो जाओ। \n',
#  '\t इसे ले जाओ। \n',
#  '\t इसे ले जाओ। \n',
#  '\t अंदर जाओ। \n',
#  '\t सोने जाओ। \n',
#  '\t सोने जाओ। \n',
#  '\t आपको कामयाबी मिले। \n',
#  '\t आपको कामयाबी मिले। \n',
#  '\t उसे पकड़ो \n',
#  '\t उसे पकड़ो \n',
#  '\t उसे पकड़ो \n',
#  '\t उसे पकड़ो \n',
#  '\t इसे पकड़ो \n',
#  '\t इसे पकड़ो \n',
#  '\t दूर रहें। \n',
#  '\t वह बीमार है। \n',
#  '\t वह बूढ़ा है \n',
#  '\t वह एक डीजे है \n',
#  '\t वह अच्छा है \n',
#  '\t वह आलसी है \n',
#  '\t वह मेरा है। \n',
#  '\t वह अमीर है \n',
#  '\t वह सेक्सी है \n',
#  '\t मैं यहां हूं। \n',
#  '\t यहाँ  है \n',
#  '\t आद पकड़ना। \n',
#  '\t आद पकड़ना। \n',
#  '\t इसे पकड़ो \n',
#  '\t इसे पकड़ो \n',
#  '\t इसे पकड़ो \n',
#  '\t इसे पकड़ो \n',
#  '\t इतना भयानक \n',
#  '\t बहुत ही अजीब \n',
#  '\t टॉम कैसा है \n',
#  '\t टॉम कैसा है \n',
#  '\t मुझे ठंड लग रही है। \n',
#  '\t मैं अच्छा हूँ। \n',
#  '\t मैं ठीक हूं \n',
#  '\t मैं बीमार हूं। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मुझे यकीन है। \n',
#  '\t मैं तुमसे हाथ जोड़ कर प्रार्थना करता हूं। \n',
#  '\t मैं तुमसे हाथ जोड़ कर प्रार्थना करता हूं। \n',
#  '\t मैं तुमसे हाथ जोड़ कर प्रार्थना करता हूं। \n',
#  '\t मैं तुमसे हाथ जोड़ कर प्रार्थना करता हूं। \n',
#  '\t मैं चल सकता हुँ। \n',
#  '\t मैं स्की कर सकता हूँ \n',
#  '\t मैं घबरा गया \n',
#  '\t मैं घबरा गया \n',
#  '\t मैं घबरा गया \n',
#  '\t मैंने साँस छोड़ी \n',
#  '\t मैंने हार मान लिया। \n',
#  '\t मैं हार मान लेता हूं \n',
#  '\t मैं हार मानता हूं। \n',
#  '\t मैं गर्म हो गया \n',
#  '\t मैं गर्म हो गया \n',
#  '\t मुझे मज़ा आया। \n',
#  '\t मुझे मज़ा आया। \n',
#  '\t मुझे मज़ा आया। \n',
#  '\t मुझे मज़ा आया। \n',
#  '\t मुझे इससे नफरत है। \n',
#  '\t यह मेरे पास है। \n',
#  '\t मैंने टॉम को मारा \n',
#  '\t ऐसा ही हो। \n',
#  '\t मैंने जल्दी की \n',
#  '\t मैंने जल्दी की \n',
#  '\t मैंने साँस ली \n',
#  '\t मैं जानता था। \n',
#  '\t मुझे यह पसंद है। \n',
#  '\t मैंने इसे खो दिया \n',
#  '\t मुझे इससे प्यार है \n',
#  '\t मुझे इससे प्यार है। \n',
#  '\t वाकई \n',
#  '\t वाकई। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे जाना चाहिए। \n',
#  '\t मुझे इसकी आवश्यकता है। \n',
#  '\t मुझे इसकी आवश्यकता है। \n',
#  '\t मैंने ध्यान दिया। \n',
#  '\t मैंने प्रीपेड कर दिया \n',
#  '\t मैं वादा करता हूँ। \n',
#  '\t मैंने आराम किया \n',
#  '\t मैंने आराम किया \n',
#  '\t मैं सेवानिवृत्त हो गया \n',
#  '\t मैंने कहा नहीं \n',
#  '\t मैं ऐसा कहा। \n',
#  '\t मैंने उसे देखा \n',
#  '\t मैंने उसे देखा \n',
#  '\t मैंने उसे देखा \n',
#  '\t मैंने एक देखा \n',
#  '\t मैंने एक देखा \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैंने तुम्हें देखा था। \n',
#  '\t मैं टॉम को देखता हूं। \n',
#  '\t मैंने चिल्ला का कहा। \n',
#  '\t में फिसल गया। \n',
#  '\t में फिसल गया। \n',
#  '\t मुझे यह चाहिेए। \n',
#  '\t मैं नया था \n',
#  '\t मैं नया था \n',
#  '\t मैं जाऊंगा \n',
#  '\t मैं उठा। \n',
#  '\t मैं उठा। \n',
#  '\t मैं सहमत हूँ \n',
#  '\t मैं चला जाऊंगा \n',
#  '\t मैं फोन करूंगा \n',
#  '\t मैं खाना बनाऊंगा \n',
#  '\t मैं सहायता करुंगा। \n',
#  '\t मैं जीवित रहूंगा \n',
#  '\t मैं आज्ञा मानूंगा \n',
#  '\t मैं पैक कर दूँगा \n',
#  '\t मैं पैक कर दूँगा \n',
#  '\t मैं पैक कर दूँगा \n',
#  '\t मुझे रहने दो \n',
#  '\t मैं छोड़ दूंगा \n',
#  '\t मैं गाऊंगा \n',
#  '\t मैं रोक दूंगा। \n',
#  '\t मैं तैरूंगा \n',
#  '\t मैं बात करता हूँ। \n',
#  '\t मैं बात करता हूँ। \n',
#  '\t मैं इंतज़ार करूंगा। \n',
#  '\t मैं चलूँगा \n',
#  '\t मैं काम करूंगा। \n',
#  '\t मैं काम करूंगा। \n',
#  '\t मैं एक पुलिस वाला हूं \n',
#  '\t मै एक आदमी हूँ। \n',
#  '\t मैं ज़िंदा हूं। \n',
#  '\t मैं ज़िंदा हूं। \n',
#  '\t मैं ज़िंदा हूं। \n',
#  '\t मैं अकेला हूँ \n',
#  '\t मैं अकेला हूँ \n',
#  '\t मैं नाराज़ हूँ। \n',
#  '\t मैं नाराज़ हूँ। \n',
#  '\t मैं सशस्त्र हूँ \n',
#  '\t मैं सशस्त्र हूँ \n',
#  '\t मैं जगा हूँ। \n',
#  '\t मैं अंधा हुँ। \n',
#  '\t मैं टूट गया हूँ। \n',
#  '\t मैं साफ़ हूँ \n',
#  '\t मैं साफ़ हूँ \n',
#  '\t मैं सनकी हूं। \n',
#  '\t मैं सनकी हूं। \n',
#  '\t मैं ठीक हो गया हूं \n',
#  '\t मैं ठीक हो गया हूं \n',
#  '\t मुझे चक्कर आ रहे हैं। \n',
#  '\t मैं नशे में हूँ \n',
#  '\t मैं नशे में हूँ \n',
#  '\t मैं नशे में हूँ \n',
#  '\t मैं मर रहा हूं। \n',
#  '\t मैं जल्दी में हूँ \n',
#  '\t मैं पहली बार कर रहा हूँ। \n',
#  '\t मैं उधम मचा रहा हूँ \n',
#  '\t मैं उधम मचा रहा हूँ \n',
#  '\t मैं उधम मचा रहा हूँ \n',
#  '\t मैं जा रहा हूं। \n',
#  '\t मैं जा रहा हूं। \n',
#  '\t मैं जा रहा हूं। \n',
#  '\t मैं जा रहा हूं। \n',
#  '\t मैं वफादार हूं। \n',
#  '\t मैं वफादार हूं। \n',
#  '\t मैं भाग्यशाली हूं \n',
#  '\t मैं भाग्यशाली हूं \n',
#  '\t मैं भाग्यशाली हूं \n',
#  '\t मैं भाग्यशाली हूं \n',
#  '\t मैं भाग्यशाली हूं \n',
#  '\t मैं झूठ बोल रहा हूँ \n',
#  '\t मैं नंगा हूँ \n',
#  '\t मैं नंगा हूँ \n',
#  '\t मैं नंगा हूँ \n',
#  '\t मैं नंगा हूँ \n',
#  '\t मैं नंगा हूँ \n',
#  '\t मैं शांत हूं \n',
#  '\t मैं तैयार हूं \n',
#  '\t मैं तैयार हूं \n',
#  '\t मैं तैयार हूं। \n',
#  '\t मैं सही हूँ \n',
#  '\t मैं शांत हूं। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मुझे माफ़ करें। \n',
#  '\t मैं फँस गया हूँ। \n',
#  '\t मैं डरपोक हूँ \n',
#  '\t मैं थक गया हूं। \n',
#  '\t मैं सख्त हूं \n',
#  '\t मैं सख्त हूं \n',
#  '\t मैं सख्त हूं \n',
#  '\t मैं सख्त हूं \n',
#  '\t मैं तुम्हारा हूँ \n',
#  '\t मैं तुम्हारा हूँ \n',
#  '\t मैंने खोया। \n',
#  '\t क्या टॉम ठीक है \n',
#  '\t क्या टॉम ठीक है \n',
#  '\t क्या यह बुरा है \n',
#  '\t क्या यह दूर है \n',
#  '\t क्या यह दूर है \n',
#  '\t क्या गर्मी है \n',
#  '\t क्या यह आप है \n',
#  '\t क्या यह आप है \n',
#  '\t क्या यह आप है \n',
#  '\t यह असफल हो गया। \n',
#  '\t यह वरफ़ से ढक गया। \n',
#  '\t इससे बदबू आती है। \n',
#  '\t इससे बदबू आती है। \n',
#  '\t ठीक था। \n',
#  '\t ठीक था। \n',
#  '\t ठीक था। \n',
#  '\t इसने काम किया। \n',
#  '\t इसने काम किया। \n',
#  '\t अभी साढ़े तीन बजे हैं \n',
#  '\t अभी  बजे हैं \n',
#  '\t अभी  बजे हैं \n',
#  '\t यह एक टीवी है \n',
#  '\t ठंड है \n',
#  '\t ठंड है \n',
#  '\t यह अंधेरा है। \n',
#  '\t यह मर चुका है \n',
#  '\t यह मर चुका है \n',
#  '\t यह मर चुका है \n',
#  '\t यह हो चुका है। \n',
#  '\t यह आसान है \n',
#  '\t यह भोजन है \n',
#  '\t यह निःशुल्क है। \n',
#  '\t यह यहाँ है। \n',
#  '\t यह यहाँ है। \n',
#  '\t यह उसका है \n',
#  '\t यह उसका है \n',
#  '\t उसे देर हो गई है \n',
#  '\t यह खो गया है \n',
#  '\t यह मेरा है। \n',
#  '\t यह मेरा है। \n',
#  '\t यह मेरा है। \n',
#  '\t यह मेरा है। \n',
#  '\t यह खुला है \n',
#  '\t यह हमारा है। \n',
#  '\t यह हमारा है। \n',
#  '\t यह हमारा है। \n',
#  '\t यह रेत है \n',
#  '\t यह समय है। \n',
#  '\t यह समय है। \n',
#  '\t यह सच है \n',
#  '\t यह काम है। \n',
#  '\t शांत रहें। \n',
#  '\t वह रखो \n',
#  '\t वह रखो \n',
#  '\t इसे रख लो। \n',
#  '\t इसे रख लो। \n',
#  '\t जाने भी दो। \n',
#  '\t जाने भी दो। \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे जाने दो \n',
#  '\t मुझे अंदर आने दो \n',
#  '\t मुझे अंदर आने दो \n',
#  '\t चलिए पूछते हैं \n',
#  '\t चलो खाते हैं। \n',
#  '\t चलो देखते हैं। \n',
#  '\t शांत लेटो। \n',
#  '\t शांत लेटो। \n',
#  '\t शांत लेटो। \n',
#  '\t शांत लेटो। \n',
#  '\t शांत लेटो। \n',
#  '\t शांत लेटो। \n',
#  '\t दूर देखो। \n',
#  '\t दूर देखो। \n',
#  '\t पीछे देखना \n',
#  '\t पीछे देखना \n',
#  '\t यहाँ देखो। \n',
#  '\t यहाँ देखो। \n',
#  '\t ढीला करो। \n',
#  '\t ढीला करो। \n',
#  '\t ढीला करो। \n',
#  '\t ढीला करो। \n',
#  '\t ढीला करो। \n',
#  '\t खिसकना। \n',
#  '\t खिसकना। \n',
#  '\t खिसकना। \n',
#  '\t अच्छा शॉट \n',
#  '\t बिल्कुल \n',
#  '\t बिल्कुल \n',
#  '\t बिल्कुल \n',
#  '\t बिल्कुल। \n',
#  '\t बिल्कुल। \n',
#  '\t ओह कृपया \n',
#  '\t ओह कृपया \n',
#  '\t मुझे क्षमा करें \n',
#  '\t मुझे क्षमा करें \n',
#  '\t मुझे क्षमा करें \n',
#  '\t इस पढ़ें। \n',
#  '\t हैलो कहें। \n',
#  '\t ऊपर देखें। \n',
#  '\t नीचे देखें। \n',
#  '\t नीचे देखें। \n',
#  '\t उसे पकड़ें \n',
#  '\t उसे पकड़ें \n',
#  '\t गंभीरता से \n',
#  '\t गंभीरता से \n',
#  '\t गंभीरता से \n',
#  '\t वो रोई। \n',
#  '\t वो रोई। \n',
#  '\t उसने प्रयास किया। \n',
#  '\t वो चलती है। \n',
#  '\t वह बहुत उत्तेजक है। \n',
#  '\t वह बहुत उत्तेजक है। \n',
#  '\t यहाँ हस्ताक्षर कीजिए। \n',
#  '\t यहाँ हस्ताक्षर कीजिए। \n',
#  '\t इस पर हस्ताक्षर करें \n',
#  '\t इस पर हस्ताक्षर करें \n',
#  '\t गति कम करो। \n',
#  '\t गति कम करो। \n',
#  '\t दूर रहो \n',
#  '\t दूर रहो \n',
#  '\t रुको। \n',
#  '\t रुको। \n',
#  '\t शांत रहें। \n',
#  '\t शांत रहें। \n',
#  '\t शांत रहें। \n',
#  '\t शांत रहें। \n',
#  '\t शांत रहें। \n',
#  '\t नीचे रहना \n',
#  '\t नीचे रहना \n',
#  '\t नीचे रहना। \n',
#  '\t नीचे रहना। \n',
#  '\t यहाँ रहें। \n',
#  '\t यहाँ रहें। \n',
#  '\t यहाँ रहें। \n',
#  '\t पतले रहो \n',
#  '\t कदम पीछे खींचना। \n',
#  '\t कदम पीछे खींचना। \n',
#  '\t बंद करो \n',
#  '\t बंद करो। \n',
#  '\t बंद करो। \n',
#  '\t बंद करो। \n',
#  '\t उन्हें रोकें \n',
#  '\t अपना ध्यान रखना \n',
#  '\t अपना ध्यान रखना \n',
#  '\t अपना ध्यान रखना। \n',
#  '\t अपना ध्यान रखना। \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t मेरा ले लो \n',
#  '\t यह लो \n',
#  '\t यह लो \n',
#  '\t धन्यवाद। \n',
#  '\t धन्यवाद। \n',
#  '\t यह ठीक है \n',
#  '\t यह ठीक है \n',
#  '\t यह ठीक है \n',
#  '\t यह ठीक है \n',
#  '\t इतना ही। \n',
#  '\t तब क्या \n',
#  '\t वे गिर गये \n',
#  '\t वे गिर गये \n',
#  '\t वे छोड़ गए। \n',
#  '\t वे छोड़ गए। \n',
#  '\t ने झूठ बोले। \n',
#  '\t ने झूठ बोले। \n',
#  '\t वे खो गए। \n',
#  '\t वे खो गए। \n',
#  '\t वे तैरे। \n',
#  '\t वे तैरे। \n',
#  '\t वे तैरे। \n',
#  '\t वे तैरे। \n',
#  '\t समय पूर्ण हुआ। \n',
#  '\t टॉम खाना बनाता है \n',
#  '\t टॉम रोया \n',
#  '\t टॉम ठीक है \n',
#  '\t टॉम बुनता है \n',
#  '\t टॉम जानता है \n',
#  '\t टॉम रॉक्स। \n',
#  '\t टॉम बोला \n',
#  '\t टॉम ने हाथ हिलाया। \n',
#  '\t टॉम काम करता है \n',
#  '\t टॉम मोटा है \n',
#  '\t टॉम पागल है \n',
#  '\t टॉम पागल है \n',
#  '\t टॉम दुखी है \n',
#  '\t टॉम पर भरोसा रखें \n',
#  '\t टॉम पर भरोसा रखें \n',
#  '\t पुनः प्रयास करें। \n',
#  '\t पुनः प्रयास करें। \n',
#  '\t पुनः प्रयास करें। \n',
#  '\t पहनकर देखो। \n',
#  '\t बांए मुड़िए। \n',
#  '\t यहाँ इंतजार करें। \n',
#  '\t यहाँ इंतजार करें। \n',
#  '\t यहाँ इंतजार करें। \n',
#  '\t यहाँ इंतजार करें। \n',
#  '\t ध्यान रहें \n',
#  '\t ध्यान रहें \n',
#  '\t ध्यान रहें \n',
#  '\t हम सहमत हुए। \n',
#  '\t हमने यह किया \n',
#  '\t हमने यह किया। \n',
#  '\t हमने यह किया। \n',
#  '\t हम भूल गये \n',
#  '\t हमने इसे देखा \n',
#  '\t हमने इसे देखा \n',
#  '\t हम मुस्कुराए \n',
#  '\t हमने बात किया। \n',
#  '\t हमने बात किया। \n',
#  '\t हमने बात किया। \n',
#  '\t हमने बात किया। \n',
#  '\t हमने बात किया। \n',
#  '\t हमने प्रतीक्षा की। \n',
#  '\t हमने प्रतीक्षा की। \n',
#  '\t हम चल पड़े। \n',
#  '\t हम चल पड़े। \n',
#  '\t हम कोशिश करेंगे। \n',
#  '\t हम कोशिश करेंगे। \n',
#  '\t हम जीतेंगे \n',
#  '\t हम जीतेंगे \n',
#  '\t हम गर्म हैं \n',
#  '\t दु खी थे। \n',
#  ...]

# %%
input_token_index = dict(
    [(char,i) for i, char in enumerate(input_characters)]
)
target_token_index = dict(
    [(char,i) for i, char in enumerate(target_characters)]
)

# %%
encoder_input_data = np.zeros(
    (len(input_texts),max_encoder_seq_len, num_encoder_tokens),
    dtype = 'float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_len, num_decoder_tokens),    
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_len, num_decoder_tokens),
    dtype = 'float32')

# %%
encoder_input_data.shape
# Out:
# (15000, 16, 27)

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1
    encoder_input_data[i, t+1:, input_token_index[' ']] = 1
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]]=1
        if t>0:
            decoder_target_data[i, t-1, target_token_index[char]]=1
    decoder_input_data[i,t+1:, target_token_index[' ']] = 1
    decoder_target_data[i, t:, target_token_index[' ']]=1

# %%
encoder_input_data[0].shape
# Out:
# (16, 27)

# %% [markdown]
# # Model

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate, TimeDistributed, Attention

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]
# Out:
# 2024-08-23 12:36:45.808115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9474 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5

# %%
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs,_,_ = decoder_lstm(decoder_inputs, initial_state = encoder_states)

# Attention
attention = Attention()
context_vector = attention([decoder_outputs, encoder_outputs])

# Concatenate context vector and LSTM output
decoder_combined_context = Concatenate(axis=-1)([context_vector, decoder_outputs])

decoder_dense = Dense(num_decoder_tokens, activation = 'softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit([encoder_input_data, decoder_input_data], decoder_target_data, 
         batch_size = batch_size,
         epochs=epochs,
         validation_split=0.2)
# Out:
# Epoch 1/100
# 2024-08-23 12:37:56.810919: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6699 - loss: 1.6824 - val_accuracy: 0.6649 - val_loss: 1.3524
# Epoch 2/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7100 - loss: 1.1748 - val_accuracy: 0.7231 - val_loss: 1.0908
# Epoch 3/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7665 - loss: 0.9178 - val_accuracy: 0.7534 - val_loss: 0.9305
# Epoch 4/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7932 - loss: 0.7914 - val_accuracy: 0.7750 - val_loss: 0.8531
# Epoch 5/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8069 - loss: 0.7238 - val_accuracy: 0.7829 - val_loss: 0.8000
# Epoch 6/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8176 - loss: 0.6771 - val_accuracy: 0.7917 - val_loss: 0.7619
# Epoch 7/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8242 - loss: 0.6444 - val_accuracy: 0.8015 - val_loss: 0.7357
# Epoch 8/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8310 - loss: 0.6179 - val_accuracy: 0.8047 - val_loss: 0.7173
# Epoch 9/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8363 - loss: 0.5959 - val_accuracy: 0.8142 - val_loss: 0.6830
# Epoch 10/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8440 - loss: 0.5683 - val_accuracy: 0.8105 - val_loss: 0.6937
# Epoch 11/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8468 - loss: 0.5527 - val_accuracy: 0.8174 - val_loss: 0.6638
# Epoch 12/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8525 - loss: 0.5320 - val_accuracy: 0.8234 - val_loss: 0.6485
# Epoch 13/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8569 - loss: 0.5170 - val_accuracy: 0.8239 - val_loss: 0.6429
# Epoch 14/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8596 - loss: 0.5053 - val_accuracy: 0.8290 - val_loss: 0.6230
# Epoch 15/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8641 - loss: 0.4891 - val_accuracy: 0.8281 - val_loss: 0.6261
# Epoch 16/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8668 - loss: 0.4767 - val_accuracy: 0.8239 - val_loss: 0.6332
# Epoch 17/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8686 - loss: 0.4679 - val_accuracy: 0.8320 - val_loss: 0.6077
# Epoch 18/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8739 - loss: 0.4498 - val_accuracy: 0.8334 - val_loss: 0.6069
# Epoch 19/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8765 - loss: 0.4402 - val_accuracy: 0.8356 - val_loss: 0.6011
# Epoch 20/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8794 - loss: 0.4311 - val_accuracy: 0.8364 - val_loss: 0.5984
# Epoch 21/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8823 - loss: 0.4202 - val_accuracy: 0.8355 - val_loss: 0.6008
# Epoch 22/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8848 - loss: 0.4114 - val_accuracy: 0.8360 - val_loss: 0.5993
# Epoch 23/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8876 - loss: 0.4018 - val_accuracy: 0.8374 - val_loss: 0.5963
# Epoch 24/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8905 - loss: 0.3920 - val_accuracy: 0.8412 - val_loss: 0.5879
# Epoch 25/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8932 - loss: 0.3810 - val_accuracy: 0.8406 - val_loss: 0.5884
# Epoch 26/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8948 - loss: 0.3778 - val_accuracy: 0.8405 - val_loss: 0.5882
# Epoch 27/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8981 - loss: 0.3655 - val_accuracy: 0.8377 - val_loss: 0.5971
# Epoch 28/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9010 - loss: 0.3547 - val_accuracy: 0.8403 - val_loss: 0.5925
# Epoch 29/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9022 - loss: 0.3516 - val_accuracy: 0.8413 - val_loss: 0.5885
# Epoch 30/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9051 - loss: 0.3435 - val_accuracy: 0.8422 - val_loss: 0.5920
# Epoch 31/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9069 - loss: 0.3343 - val_accuracy: 0.8403 - val_loss: 0.5976
# Epoch 32/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9088 - loss: 0.3293 - val_accuracy: 0.8407 - val_loss: 0.5987
# Epoch 33/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9105 - loss: 0.3239 - val_accuracy: 0.8395 - val_loss: 0.5985
# Epoch 34/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9133 - loss: 0.3140 - val_accuracy: 0.8402 - val_loss: 0.6003
# Epoch 35/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9146 - loss: 0.3091 - val_accuracy: 0.8409 - val_loss: 0.6013
# Epoch 36/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9166 - loss: 0.3027 - val_accuracy: 0.8422 - val_loss: 0.5989
# Epoch 37/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9178 - loss: 0.2977 - val_accuracy: 0.8416 - val_loss: 0.6025
# Epoch 38/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9200 - loss: 0.2884 - val_accuracy: 0.8401 - val_loss: 0.6150
# Epoch 39/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9223 - loss: 0.2822 - val_accuracy: 0.8435 - val_loss: 0.6064
# Epoch 40/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9232 - loss: 0.2786 - val_accuracy: 0.8423 - val_loss: 0.6138
# Epoch 41/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9246 - loss: 0.2745 - val_accuracy: 0.8411 - val_loss: 0.6196
# Epoch 42/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9271 - loss: 0.2663 - val_accuracy: 0.8412 - val_loss: 0.6201
# Epoch 43/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9277 - loss: 0.2626 - val_accuracy: 0.8400 - val_loss: 0.6243
# Epoch 44/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9294 - loss: 0.2567 - val_accuracy: 0.8427 - val_loss: 0.6263
# Epoch 45/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9308 - loss: 0.2530 - val_accuracy: 0.8409 - val_loss: 0.6276
# Epoch 46/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9321 - loss: 0.2467 - val_accuracy: 0.8399 - val_loss: 0.6374
# Epoch 47/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9336 - loss: 0.2426 - val_accuracy: 0.8416 - val_loss: 0.6367
# Epoch 48/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9350 - loss: 0.2366 - val_accuracy: 0.8378 - val_loss: 0.6553
# Epoch 49/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9358 - loss: 0.2343 - val_accuracy: 0.8395 - val_loss: 0.6470
# Epoch 50/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9377 - loss: 0.2284 - val_accuracy: 0.8410 - val_loss: 0.6555
# Epoch 51/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9388 - loss: 0.2240 - val_accuracy: 0.8406 - val_loss: 0.6548
# Epoch 52/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9408 - loss: 0.2176 - val_accuracy: 0.8388 - val_loss: 0.6714
# Epoch 53/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9410 - loss: 0.2159 - val_accuracy: 0.8410 - val_loss: 0.6603
# Epoch 54/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9425 - loss: 0.2092 - val_accuracy: 0.8404 - val_loss: 0.6700
# Epoch 55/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9440 - loss: 0.2045 - val_accuracy: 0.8397 - val_loss: 0.6748
# Epoch 56/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9450 - loss: 0.2026 - val_accuracy: 0.8402 - val_loss: 0.6739
# Epoch 57/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9460 - loss: 0.1983 - val_accuracy: 0.8404 - val_loss: 0.6775
# Epoch 58/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9471 - loss: 0.1949 - val_accuracy: 0.8402 - val_loss: 0.6868
# Epoch 59/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9477 - loss: 0.1924 - val_accuracy: 0.8391 - val_loss: 0.6878
# Epoch 60/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9494 - loss: 0.1873 - val_accuracy: 0.8393 - val_loss: 0.6942
# Epoch 61/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9499 - loss: 0.1852 - val_accuracy: 0.8416 - val_loss: 0.6967
# Epoch 62/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9519 - loss: 0.1786 - val_accuracy: 0.8390 - val_loss: 0.7083
# Epoch 63/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9520 - loss: 0.1780 - val_accuracy: 0.8375 - val_loss: 0.7125
# Epoch 64/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9533 - loss: 0.1730 - val_accuracy: 0.8383 - val_loss: 0.7138
# Epoch 65/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9535 - loss: 0.1711 - val_accuracy: 0.8384 - val_loss: 0.7198
# Epoch 66/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9548 - loss: 0.1666 - val_accuracy: 0.8381 - val_loss: 0.7264
# Epoch 67/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9562 - loss: 0.1630 - val_accuracy: 0.8381 - val_loss: 0.7296
# Epoch 68/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9572 - loss: 0.1593 - val_accuracy: 0.8370 - val_loss: 0.7374
# Epoch 69/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9575 - loss: 0.1577 - val_accuracy: 0.8377 - val_loss: 0.7391
# Epoch 70/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9586 - loss: 0.1535 - val_accuracy: 0.8382 - val_loss: 0.7479
# Epoch 71/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9593 - loss: 0.1510 - val_accuracy: 0.8349 - val_loss: 0.7604
# Epoch 72/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9607 - loss: 0.1475 - val_accuracy: 0.8351 - val_loss: 0.7637
# Epoch 73/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9607 - loss: 0.1470 - val_accuracy: 0.8359 - val_loss: 0.7645
# Epoch 74/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9615 - loss: 0.1436 - val_accuracy: 0.8346 - val_loss: 0.7723
# Epoch 75/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9626 - loss: 0.1397 - val_accuracy: 0.8376 - val_loss: 0.7702
# Epoch 76/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9633 - loss: 0.1371 - val_accuracy: 0.8350 - val_loss: 0.7820
# Epoch 77/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9642 - loss: 0.1344 - val_accuracy: 0.8351 - val_loss: 0.7850
# Epoch 78/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9648 - loss: 0.1319 - val_accuracy: 0.8371 - val_loss: 0.7849
# Epoch 79/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9653 - loss: 0.1299 - val_accuracy: 0.8364 - val_loss: 0.7984
# Epoch 80/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9662 - loss: 0.1269 - val_accuracy: 0.8344 - val_loss: 0.8079
# Epoch 81/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9665 - loss: 0.1260 - val_accuracy: 0.8353 - val_loss: 0.8037
# Epoch 82/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9676 - loss: 0.1225 - val_accuracy: 0.8341 - val_loss: 0.8139
# Epoch 83/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9681 - loss: 0.1199 - val_accuracy: 0.8353 - val_loss: 0.8138
# Epoch 84/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9691 - loss: 0.1171 - val_accuracy: 0.8352 - val_loss: 0.8233
# Epoch 85/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9697 - loss: 0.1148 - val_accuracy: 0.8338 - val_loss: 0.8333
# Epoch 86/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9696 - loss: 0.1145 - val_accuracy: 0.8356 - val_loss: 0.8316
# Epoch 87/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9705 - loss: 0.1107 - val_accuracy: 0.8340 - val_loss: 0.8377
# Epoch 88/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9712 - loss: 0.1093 - val_accuracy: 0.8350 - val_loss: 0.8397
# Epoch 89/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9720 - loss: 0.1062 - val_accuracy: 0.8331 - val_loss: 0.8433
# Epoch 90/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9729 - loss: 0.1041 - val_accuracy: 0.8334 - val_loss: 0.8630
# Epoch 91/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9728 - loss: 0.1027 - val_accuracy: 0.8339 - val_loss: 0.8606
# Epoch 92/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9736 - loss: 0.1004 - val_accuracy: 0.8327 - val_loss: 0.8614
# Epoch 93/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9743 - loss: 0.0971 - val_accuracy: 0.8340 - val_loss: 0.8659
# Epoch 94/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9749 - loss: 0.0965 - val_accuracy: 0.8319 - val_loss: 0.8818
# Epoch 95/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9753 - loss: 0.0948 - val_accuracy: 0.8321 - val_loss: 0.8834
# Epoch 96/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9757 - loss: 0.0929 - val_accuracy: 0.8335 - val_loss: 0.8871
# Epoch 97/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9765 - loss: 0.0901 - val_accuracy: 0.8333 - val_loss: 0.8843
# Epoch 98/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9767 - loss: 0.0894 - val_accuracy: 0.8331 - val_loss: 0.8872
# Epoch 99/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9776 - loss: 0.0866 - val_accuracy: 0.8327 - val_loss: 0.9053
# Epoch 100/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9781 - loss: 0.0851 - val_accuracy: 0.8322 - val_loss: 0.9017

# %%
encoder_model = Model(encoder_inputs,encoder_states)
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h,decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state= decoder_states_inputs)
decoder_states=[state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model([decoder_inputs]+decoder_states_inputs, [decoder_outputs]+decoder_states)

# %%
reverse_input_char_index= dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index= dict((i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    
    states_value = encoder_model.predict(input_seq, verbose=0)
    
    target_seq = np.zeros((1,1, num_decoder_tokens))
    
    target_seq[0, 0, target_token_index['\t']]=1.
    
    stop_condition= False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h,c = decoder_model.predict([target_seq]+states_value, verbose=0)
        sampled_token_index = np.argmax(output_tokens[0,-1,:])
       
        sampled_char = reverse_target_char_index[sampled_token_index]
        
        decoded_sentence += sampled_char
        if (sampled_char=='\n' or len(decoded_sentence)>max_decoder_seq_len):
            stop_condition=True

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0,0, sampled_token_index]=1.
        
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(500,600,1):
    input_seq = encoder_input_data[seq_index:seq_index+1]
    decode_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence  :', input_texts[seq_index])
    print('Decoded Sentence:', decode_sentence)
# Out:
# -
# Input sentence  : catch tom
# Decoded Sentence:  टॉम को पकड़ो
#
# -
# Input sentence  : catch tom
# Decoded Sentence:  टॉम को पकड़ो
#
# -
# Input sentence  : catch him
# Decoded Sentence:  इसे दीखों
#
# -
# Input sentence  : chill out
# Decoded Sentence:  मज़े करें।
#
# -
# Input sentence  : come back
# Decoded Sentence:  वापस आओ।
#
# -
# Input sentence  : come back
# Decoded Sentence:  वापस आओ।
#
# -
# Input sentence  : come here
# Decoded Sentence:  यहाँ आओ।
#
# -
# Input sentence  : come here
# Decoded Sentence:  यहाँ आओ।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come over
# Decoded Sentence:  मिलने आना।
#
# -
# Input sentence  : come soon
# Decoded Sentence:  जल्दी आओ।
#
# -
# Input sentence  : come soon
# Decoded Sentence:  जल्दी आओ।
#
# -
# Input sentence  : cool down
# Decoded Sentence:  कोई बात
#
# -
# Input sentence  : did i win
# Decoded Sentence:  क्या मैंने जीत लिया
#
# -
# Input sentence  : did i win
# Decoded Sentence:  क्या मैंने जीत लिया
#
# -
# Input sentence  : did i win
# Decoded Sentence:  क्या मैंने जीत लिया
#
# -
# Input sentence  : do it now
# Decoded Sentence:  इसे आवकी करें।
#
# -
# Input sentence  : dogs bark
# Decoded Sentence:  कुत्ते भौंकते हैं।
#
# -
# Input sentence  : dogs bark
# Decoded Sentence:  कुत्ते भौंकते हैं।
#
# -
# Input sentence  : dont ask
# Decoded Sentence:  जाओ मा
#
# -
# Input sentence  : dont cry
# Decoded Sentence:  जाओ मा पहाला
#
# -
# Input sentence  : dont die
# Decoded Sentence:  मरो मत
#
# -
# Input sentence  : dont die
# Decoded Sentence:  मरो मत
#
# -
# Input sentence  : dont lie
# Decoded Sentence:  मतलनामा मन करो
#
# -
# Input sentence  : dont run
# Decoded Sentence:  भागो मत
#
# -
# Input sentence  : dont run
# Decoded Sentence:  भागो मत
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : excuse me
# Decoded Sentence:  माफ़ करें
#
# -
# Input sentence  : fantastic
# Decoded Sentence:  ज़बरदस्त हो
#
# -
# Input sentence  : feel this
# Decoded Sentence:  इसे महसूस करो
#
# -
# Input sentence  : feel this
# Decoded Sentence:  इसे महसूस करो
#
# -
# Input sentence  : feel this
# Decoded Sentence:  इसे महसूस करो
#
# -
# Input sentence  : feel this
# Decoded Sentence:  इसे महसूस करो
#
# -
# Input sentence  : follow me
# Decoded Sentence:  अकेले आओ
#
# -
# Input sentence  : follow us
# Decoded Sentence:  हमारे पर का पालन करें
#
# -
# Input sentence  : follow us
# Decoded Sentence:  हमारे पर का पालन करें
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : forget it
# Decoded Sentence:  रहने भी दो
#
# -
# Input sentence  : get a job
# Decoded Sentence:  नौकरी मिलना।
#
# -
# Input sentence  : get a job
# Decoded Sentence:  नौकरी मिलना।
#
# -
# Input sentence  : get a job
# Decoded Sentence:  नौकरी मिलना।
#
# -
# Input sentence  : get a job
# Decoded Sentence:  नौकरी मिलना।
#
# -
# Input sentence  : get ready
# Decoded Sentence:  तैयार हो जाओ।
#
# -
# Input sentence  : get ready
# Decoded Sentence:  तैयार हो जाओ।
#
# -
# Input sentence  : go get it
# Decoded Sentence:  इसे ले जाओ।
#
# -
# Input sentence  : go get it
# Decoded Sentence:  इसे ले जाओ।
#
# -
# Input sentence  : go inside
# Decoded Sentence:  बंड करो
#
# -
# Input sentence  : go to bed
# Decoded Sentence:  सोने जाओ।
#
# -
# Input sentence  : go to bed
# Decoded Sentence:  सोने जाओ।
#
# -
# Input sentence  : good luck
# Decoded Sentence:  पीछे देखना
#
# -
# Input sentence  : good luck
# Decoded Sentence:  पीछे देखना
#
# -
# Input sentence  : grab that
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : grab that
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : grab that
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : grab that
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : grab this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : grab this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : hands off
# Decoded Sentence:  दूठ रहाओ।
#
# -
# Input sentence  : he is ill
# Decoded Sentence:  वह एक बंबारह है।
#
# -
# Input sentence  : he is old
# Decoded Sentence:  वह आया।
#
# -
# Input sentence  : hes a dj
# Decoded Sentence:  वह एक डीजे है
#
# -
# Input sentence  : hes good
# Decoded Sentence:  वह अंदर नहीं है
#
# -
# Input sentence  : hes lazy
# Decoded Sentence:  वह अवे है।
#
# -
# Input sentence  : hes mine
# Decoded Sentence:  वह मेरा है।
#
# -
# Input sentence  : hes rich
# Decoded Sentence:  वह मेरा है
#
# -
# Input sentence  : hes sexy
# Decoded Sentence:  वह स्विस है
#
# -
# Input sentence  : here i am
# Decoded Sentence:  मैं यहां हूं।
#
# -
# Input sentence  : heres
# Decoded Sentence:  यहाँ महसे सहुत्तन करें
#
# -
# Input sentence  : hold fire
# Decoded Sentence:  आद पकड़ना।
#
# -
# Input sentence  : hold fire
# Decoded Sentence:  आद पकड़ना।
#
# -
# Input sentence  : hold this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : hold this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : hold this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : hold this
# Decoded Sentence:  इसे पकड़ो
#
# -
# Input sentence  : how awful
# Decoded Sentence:   बजे के बारे में क्या ख़याल है
#
# -
# Input sentence  : how weird
# Decoded Sentence:  कितना गया।
#
# -
# Input sentence  : hows tom
# Decoded Sentence:  टॉम कैसा है
#
# -
# Input sentence  : hows tom
# Decoded Sentence:  टॉम कैसा है
#
# -
# Input sentence  : i am cold
# Decoded Sentence:  मैं बीमार हूं।
#
# -
# Input sentence  : i am good
# Decoded Sentence:  मैं बीमार हूं।
#
# -
# Input sentence  : i am okay
# Decoded Sentence:  मैं वह कर सकता हूँ।
#
# -
# Input sentence  : i am sick
# Decoded Sentence:  मुझे तैरना चाहिए
#
# -
# Input sentence  : i am sure
# Decoded Sentence:  मैं वहां काम करता हूं
#
# -
# Input sentence  : i am sure
# Decoded Sentence:  मैं वहां काम करता हूं
#
# -
# Input sentence  : i beg you
# Decoded Sentence:  मैं तुमसे हाथ जोड़ कर प्रार्थन करता हूं।
